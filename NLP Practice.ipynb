# %%
import numpy as np
x=np.random.rand(5)
x
# %timeit x
# Out:
# 24.4 ns ± 3.78 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
import nltk

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
len(text2)
# Out:
# 141576

# %%
text1.concordance("he")
# Out:
# Displaying 25 of 1896 matches:
#  , body , and brain ; I see him now . He was ever dusting his old lexicons and
#  all the known nations of the world . He loved to dust his old grammars ; it s
# p whatever random allusions to whales he could anyways find in any book whatso
#  Leviathan that crooked serpent ; and he shall slay the dragon that is in the
#  ' S LUCIAN . " THE TRUE HISTORY ." " He visited this country also with a view
# reat value for their teeth , of which he brought some to the king . ... The be
# rty - eight , some fifty yards long . He said that he was one of six who had k
#  some fifty yards long . He said that he was one of six who had killed sixty i
# encer ' s Talus with his modern flail He threatens ruin with his ponderous tai
# .. Their fixed jav ' lins in his side he wears , And on his back a grove of pi
# . One of our harpooneers told me that he caught once a whale in Spitzbergen th
#  Atlantic is ; Not a fatter fish than he , Flounders round the Polar Sea ." --
# " answered Tom ; " I saw his sprout ; he threw up a pair of as pretty rainbows
# s a Christian would wish to look at . He ' s a raal oil - butt , that fellow !
#  -- SCORESBY . " Mad with the agonies he endures from these fresh attacks , th
# ted Sperm Whale rolls over and over ; he rears his enormous head , and with wi
# jaws snaps at everything around him ; he rushes at the boats with his head ; t
# . Being once pursued by a whale which he had wounded , he parried the assault
# ued by a whale which he had wounded , he parried the assault for some time wit
# the mate , as upon turning his head , he saw the distended jaws of a large Spe
# s legs , set his feet a - going , and he will infallibly lead you to water , i
# ed for ever . But here is an artist . He desires to paint you the dreamiest ,
#  the Saco . What is the chief element he employs ? There stand his trees , eac
# ate whether to buy him a coat , which he sadly needed , or invest his money in
# that story of Narcissus , who because he could not grasp the tormenting , mild

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
text4.dispersion_plot(["every"])

# %%
len(text8)
# Out:
# 4867

# %%
h=set('hio,dsl,kjsdlgh')

# %%
h
# Out:
# {',', 'd', 'g', 'h', 'i', 'j', 'k', 'l', 'o', 's'}

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
fdist=FreqDist(text4)
fdist
voc=fdist.keys()
voc
# Out:
# dict_keys(['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'House', 'Representatives', ':', 'Among', 'vicissitudes', 'incident', 'to', 'life', 'no', 'event', 'could', 'have', 'filled', 'me', 'with', 'greater', 'anxieties', 'than', 'that', 'which', 'notification', 'was', 'transmitted', 'by', 'your', 'order', ',', 'received', 'on', '14th', 'day', 'present', 'month', '.', 'On', 'one', 'hand', 'I', 'summoned', 'my', 'Country', 'whose', 'voice', 'can', 'never', 'hear', 'but', 'veneration', 'love', 'from', 'a', 'retreat', 'had', 'chosen', 'fondest', 'predilection', 'in', 'flattering', 'hopes', 'an', 'immutable', 'decision', 'as', 'asylum', 'declining', 'years', '--', 'rendered', 'every', 'more', 'necessary', 'well', 'dear', 'addition', 'habit', 'inclination', 'frequent', 'interruptions', 'health', 'gradual', 'waste', 'committed', 'it', 'time', 'other', 'magnitude', 'difficulty', 'trust', 'country', 'called', 'being', 'sufficient', 'awaken', 'wisest', 'most', 'experienced', 'her', 'citizens', 'distrustful', 'scrutiny', 'into', 'his', 'qualifications', 'not', 'overwhelm', 'despondence', 'who', '(', 'inheriting', 'inferior', 'endowments', 'nature', 'unpracticed', 'duties', 'civil', 'administration', ')', 'ought', 'be', 'peculiarly', 'conscious', 'own', 'deficiencies', 'In', 'this', 'conflict', 'emotions', 'all', 'dare', 'aver', 'is', 'has', 'been', 'faithful', 'study', 'collect', 'duty', 'just', 'appreciation', 'circumstance', 'might', 'affected', 'All', 'hope', 'if', 'executing', 'task', 'too', 'much', 'swayed', 'grateful', 'remembrance', 'former', 'instances', 'or', 'affectionate', 'sensibility', 'transcendent', 'proof', 'confidence', 'fellow', 'thence', 'little', 'consulted', 'incapacity', 'disinclination', 'for', 'weighty', 'untried', 'cares', 'before', 'error', 'will', 'palliated', 'motives', 'mislead', 'its', 'consequences', 'judged', 'some', 'share', 'partiality', 'they', 'originated', 'Such', 'impressions', 'under', 'obedience', 'public', 'summons', 'repaired', 'station', 'would', 'improper', 'omit', 'first', 'official', 'act', 'fervent', 'supplications', 'Almighty', 'Being', 'rules', 'over', 'universe', 'presides', 'councils', 'nations', 'providential', 'aids', 'supply', 'human', 'defect', 'His', 'benediction', 'may', 'consecrate', 'liberties', 'happiness', 'people', 'United', 'States', 'Government', 'instituted', 'themselves', 'these', 'essential', 'purposes', 'enable', 'instrument', 'employed', 'execute', 'success', 'functions', 'allotted', 'charge', 'tendering', 'homage', 'Great', 'Author', 'private', 'good', 'assure', 'myself', 'expresses', 'sentiments', 'less', 'nor', 'those', 'at', 'large', 'either', 'No', 'bound', 'acknowledge', 'adore', 'Invisible', 'Hand', 'conducts', 'affairs', 'men', 'Every', 'step', 'advanced', 'character', 'independent', 'nation', 'seems', 'distinguished', 'token', 'agency', ';', 'important', 'revolution', 'accomplished', 'system', 'their', 'united', 'government', 'tranquil', 'deliberations', 'voluntary', 'consent', 'so', 'many', 'distinct', 'communities', 'resulted', 'compared', 'means', 'governments', 'established', 'without', 'return', 'pious', 'gratitude', 'along', 'humble', 'anticipation', 'future', 'blessings', 'past', 'seem', 'presage', 'These', 'reflections', 'arising', 'out', 'crisis', 'forced', 'strongly', 'mind', 'suppressed', 'You', 'join', 'thinking', 'there', 'are', 'none', 'influence', 'proceedings', 'new', 'free', 'auspiciously', 'commence', 'By', 'article', 'establishing', 'executive', 'department', 'made', 'President', '"', 'recommend', 'consideration', 'such', 'measures', 'he', 'shall', 'judge', 'expedient', '."', 'The', 'circumstances', 'now', 'meet', 'you', 'acquit', 'entering', 'subject', 'further', 'refer', 'great', 'constitutional', 'charter', 'assembled', 'defining', 'powers', 'designates', 'objects', 'attention', 'given', 'It', 'consistent', 'far', 'congenial', 'feelings', 'actuate', 'substitute', 'place', 'recommendation', 'particular', 'tribute', 'due', 'talent ...

# %%
fdist['citizens']
# Out:
# 241

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fdist.plot(40, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
fdist.jointplot(40, cumulative=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 fdist.jointplot(40, cumulative=True)
#
# AttributeError: 'FreqDist' object has no attribute 'jointplot'

# %%
fdist.hapaxes()
# Out:
# ['notification',
#  '14th',
#  'fondest',
#  'predilection',
#  'flattering',
#  'asylum',
#  'interruptions',
#  'awaken',
#  'distrustful',
#  'despondence',
#  'inheriting',
#  'endowments',
#  'unpracticed',
#  'aver',
#  'thence',
#  'consulted',
#  'disinclination',
#  'untried',
#  'cares',
#  'palliated',
#  'mislead',
#  'repaired',
#  'improper',
#  'omit',
#  'tendering',
#  'homage',
#  'adore',
#  'Invisible',
#  'conducts',
#  'token',
#  'pious',
#  'reflections',
#  'auspiciously',
#  'acquit',
#  'designates',
#  'congenial',
#  'actuate',
#  'rectitude',
#  'adorn',
#  'behold',
#  'misdirect',
#  'preeminence',
#  'indissoluble',
#  'disregards',
#  'fifth',
#  'juncture',
#  'inquietude',
#  'discernment',
#  'characteristic',
#  'impregnably',
#  'renounce',
#  'inapplicable',
#  'emoluments',
#  'indispensably',
#  'Parent',
#  'Race',
#  'supplication',
#  'deliberating',
#  'arrive',
#  'Previous',
#  'upbraidings',
#  'perceived',
#  'legislature',
#  'apprehensive',
#  'fleets',
#  'consisting',
#  'broke',
#  'pieces',
#  'rod',
#  'models',
#  'Batavian',
#  'particulars',
#  'courier',
#  'foreseen',
#  'Negligence',
#  'melancholy',
#  'languor',
#  'rivalries',
#  'conventions',
#  'Measures',
#  'disquisitions',
#  'issued',
#  'Employed',
#  'Irritated',
#  'literary',
#  'altercation',
#  'heated',
#  'animosity',
#  'Claiming',
#  'rejection',
#  'ordain',
#  'Returning',
#  'repeatedly',
#  'solidity',
#  'congregations',
#  'intelligences',
#  'Chamber',
#  'decoration',
#  'robes',
#  'diamonds',
#  'descends',
#  'accidents',
#  'antiquity',
#  'dissemination',
#  'justifiable',
#  'excusable',
#  'grandeur',
#  'innocence',
#  'infect',
#  'procured',
#  'artifice',
#  'solitary',
#  'flattery',
#  'menaces',
#  'venality',
#  'merited',
#  'praises',
#  'delicious',
#  'recollection',
#  'rampart',
#  'northern',
#  'unessential',
#  'denominations',
#  'academies',
#  'propagating',
#  'sophistry',
#  'pestilence',
#  'meliorate',
#  'inclining',
#  'applauded',
#  'residence',
#  'investigate',
#  'colorable',
#  'complaint',
#  'reparation',
#  'hazarded',
#  'engraven',
#  'comply',
#  'strenuous',
#  'Patron',
#  'Fountain',
#  'Protector',
#  'Friends',
#  'presentiments',
#  'traversing',
#  'Utterly',
#  'gentlemen',
#  'steer',
#  'vessel',
#  'embarked',
#  'dreary',
#  'bled',
#  'despotic',
#  'persecutions',
#  'throes',
#  'convulsions',
#  'agonizing',
#  'spasms',
#  'infuriated',
#  'slaughter',
#  'billows',
#  'Federalists',
#  'theoretic',
#  'visionary',
#  'Kindly',
#  'exterminating',
#  'havoc',
#  'degradations',
#  'entertaining',
#  'adoring',
#  'delights',
#  'mouth',
#  'felicities',
#  'compress',
#  'bulwarks',
#  'lopped',
#  'peaceable',
#  'unprovided',
#  'regulars',
#  'lightly',
#  'burthened',
#  'handmaid',
#  'arraignment',
#  'habeas',
#  'corpus',
#  'text',
#  'touchstone',
#  'retrace',
#  'regain',
#  'learnt',
#  'fairest',
#  'intentional',
#  'conciliate',
#  'Infinite',
#  'Proceeding',
#  'entrance',
#  'endeavored',
#  'soundly',
#  'bridle',
#  'discontinue',
#  'covering',
#  'intrusions',
#  'domiciliary',
#  'vexation',
#  'fell',
#  'laborer',
#  'taxgatherer',
#  'contracts',
#  'repartition',
#  'burthening',
#  'suspension',
#  'accruing',
#  'disapproved',
#  'opposite',
#  'commiseration',
#  'Endowed',
#  'breathing',
#  'stream',
#  'overflowing',
#  'divert',
#  'hunter',
#  'bodily',
#  'instructors',
#  'combated',
#  'crafty',
#  'sanctimonious',
#  'antiphilosophists',
#  'ascendancy',
#  'arrogate',
#  'confide',
#  'leveled',
#  'regretted',
#  'inasmuch',
#  'punishments',
#  'offenders',
#  'uninteresting',
#  'propagation',
#  'latent',
#  'proceeded',
#  'pronounced',
#  'defamatory',
#  'publications',
#  'renders',
#  'coercions',
#  'noted',
#  'league',
#  'reasoning',
#  'hearing',
#  'improprieties',
#  'censorship',
#  'Contemplating',
#  'auguring',
#  'congratulations',
#  'rallied',
#  'piercing',
#  'veil',
#  'doubting',
#  'unassailed',
#  'competitions',
#  'seduce',
#  'Israel',
#  'flowing',
#  'riper',
#  'impression',
#  'inexpressibly',
#  'severely',
#  'wasteful',
#  'Proofs',
#  'distressing',
#  'chargeable',
#  'unwarrantable',
#  'Indulging',
#  'trespass',
#  'fulfilling',
#  'assertions',
#  'unexceptionable',
#  'rage',
#  'retaliation',
#  'edicts',
#  'demonstrations',
#  'revocation',
#  'Assuring',
#  'vicissitude',
#  'inadequacy',
#  'accommodation',
#  'partialities',
#  'invade',
#  'exempted',
#  'aliment',
#  'meritoriously',
#  'conversion',
#  'wretchedness',
#  'manners',
#  'suppressing',
#  'regulates',
#  'devout',
#  'publicly',
#  'repeating',
#  'estimated',
#  'stamped',
#  'postulations',
#  'provoking',
#  'discontinued',
#  'disgraceful',
#  'unlawfulness',
#  'cruising',
#  'records',
#  'waged',
#  'usages',
#  'traitors',
#  'deserters',
#  'emigrating',
#  'avowed',
#  'naturalizing',
#  'battles',
#  'hatchet',
#  'knife',
#  'indiscriminate',
#  'loose',
#  'savages',
#  'allured',
#  'glut',
#  'defenseless',
#  'commanders',
#  'extorted',
#  'awaiting',
#  'disorganize',
#  'recoil',
#  'emanate',
#  'inconsistencies',
#  'disorganizing',
#  'insurrectional',
#  'scabbard',
#  'apprised',
#  'resheathed',
#  'Isles',
#  'abounds',
#  'cabinet',
#  'recoiled',
#  'draining',
#  'vaults',
#  'seasonable',
#  'cheerfulness',
#  'thrown',
#  'presaging',
#  'flashes',
#  'destitute',
#  'Conscious',
#  'calculating',
#  'appreciated',
#  'felicitate',
#  'parental',
#  'enjoying',
#  'partition',
#  'police',
#  'maturity',
#  'vows',
#  'prefers',
#  'convulsed',
#  'Destructive',
#  'ensued',
#  'aloof',
#  'committing',
#  'Fortunate',
#  'Situated',
#  'zone',
#  'latitude',
#  'varieties',
#  'Penetrating',
#  'internally',
#  'Lakes',
#  'Blessed',
#  'prospers',
#  'Local',
#  'recompensed',
#  'nursery',
#  'patronizes',
#  'explaining',
#  'infusing',
#  'depositaries',
#  'Had',
#  'retains',
#  'healthful',
#  'corrupt',
#  'populace',
#  'incapable',
#  'Usurpation',
#  'usurper',
#  'debasement',
#  'Experiencing',
#  'overset',
#  'demolish',
#  'garrison',
#  'constituting',
#  'spoliation',
#  'prominently',
#  'Invasions',
#  'comport',
#  'youthful',
#  'facilitating',
#  'shorten',
#  'distances',
#  'intersecting',
#  'bays',
#  'lakes',
#  'situated',
#  'Possessing',
#  'plunge',
#  'nourishes',
#  'cultivator',
#  'casualties',
#  'augments',
#  'flourishes',
#  'officially',
#  'guardian',
#  'purse',
#  'uselessly',
#  'defaulters',
#  'evince',
#  'relaxation',
#  'regularly',
#  'claiming',
#  'rendering',
#  'pervades',
#  'Discord',
#  'gigantic',
#  'contemplating',
#  'enlightening',
#  'meritorious',
#  'graciously',
#  'describe',
#  'evinced',
#  'announces',
#  'profoundly',
#  'ceasing',
#  'solace',
#  'surmounting',
#  'remotely',
#  '120',
#  '1816',
#  'Board',
#  'Engineers',
#  'Naval',
#  'Commissioners',
#  'inlets',
#  'detained',
#  'sailing',
#  'bay',
#  'navigable',
#  'insult',
#  'remarked',
#  'devastation',
#  'unprepared',
#  'persevered',
#  'Attention',
#  'adverted',
#  'accommodations',
#  'exertion',
#  'equipments',
#  'rigor',
#  'export',
#  'exportation',
#  'traded',
#  'adhered',
#  'Cortes',
#  'Shortly',
#  'adventurers',
#  'buccaneering',
#  'Amelia',
#  'Island',
#  'piratical',
#  'culprits',
#  'atrocious',
#  'censure',
#  'executions',
#  'transcend',
#  'pardoning',
#  'criminality',
#  'extenuating',
#  'whereof',
#  'described',
#  'opens',
#  'Province',
#  'excellent',
#  'enables',
#  'date',
#  'October',
#  '3d',
#  'expiring',
#  'Ghent',
#  'fish',
#  'Britannic',
#  'Majesty',
#  'Indies',
#  'reciprocated',
#  'summer',
#  'Barbary',
#  'Powers',
#  '1801',
#  'squadron',
#  'Mediterranean',
#  'intervened',
#  'excepted',
#  'disposing',
#  'piracy',
#  '67',
#  'excise',
#  'untouched',
#  'explained',
#  'considerably',
#  'Anxious',
#  'Independently',
#  'precarious',
#  'augment',
#  'unfortunately',
#  'retarded',
#  'paved',
#  'dense',
#  'endearing',
#  'lieu',
#  'sustenance',
#  'digest',
#  'maritime',
#  'imminent',
#  'averting',
#  'recollect',
#  'happiest',
#  'rose',
#  'anticipations',
#  'unceasingly',
#  'preyed',
#  'ascendency',
#  'exceeded',
#  'county',
#  'tumultuous',
#  'disorderly',
#  'deriving',
#  'corresponded',
#  'Perfection',
#  'tracing',
#  'Twenty',
#  'shut',
#  'outlet',
#  'tributary',
#  'upper',
#  'Red',
#  '),',
#  'uninterrupted',
#  'comprise',
#  'enumerates',
#  'Administered',
#  'doubly',
#  'unfolded',
#  'Subordinate',
#  'expounded',
#  'imperfection',
#  'jubilee',
#  'twelve',
#  'bounded',
#  'Treaties',
#  'forest',
#  'ax',
#  'woodsmen',
#  'teem',
#  'tillage',
#  'whitened',
#  'artists',
#  'unexaggerated',
#  'shades',
#  'visitation',
#  'extremities',
#  'lastly',
#  'aggravated',
#  'prepossessions',
#  'spotless',
#  'collision',
#  'kindled',
#  'imbittered',
#  'weed',
#  'uprooted',
#  'dissenting',
#  'uncontrolled',
#  'rigorous',
#  'aggravation',
#  'ark',
#  'erected',
#  'antipathies',
#  'assuaged',
#  'discarding',
#  'remnant',
#  'rancor',
#  'communion',
#  'perplexed',
#  'composition',
#  'annually',
#  'deputed',
#  'knit',
#  'metropolis',
#  'traces',
#  'surviving',
#  'warriors',
#  'revised',
#  'bee',
#  'Ocean',
#  'potentates',
#  'hunters',
#  'exploring',
#  'researches',
#  'magnificence',
#  'splendor',
#  'imperishable',
#  'glories',
#  'aqueducts',
#  'Rome',
#  'afte',
#  'conquests',
#  'swallowed',
#  'spoil',
#  'barbarians',
#  'deference',
#  'originating',
#  'unquestioned',
#  'conciliated',
#  'approximated',
#  'transcendently',
#  'scruple',
#  'oftener',
#  'Intentions',
#  'watchman',
#  'waketh',
#  'customary',
#  'convinces',
#  'admonishes',
#  'superintend',
#  'confederate',
#  'transcending',
#  'confound',
#  'inconsiderable',
#  'counteract',
#  'profuse',
#  'appropriation',
#  'impost',
#  'consist',
#  'Internal',
#  'Considering',
#  'climes',
#  'forts',
#  'dockyards',
#  'introduction',
#  'omitting',
#  'cover',
#  'impenetrable',
#  'Partial',
#  'mortifications',
#  'inscribes',
#  'legible',
#  'induces',
#  'mercifully',
#  'preparatory',
#  'allude',
#  'unadjusted',
#  'imbibed',
#  'annihilation',
#  'encroaches',
#  'impair',
#  'detract',
#  'Solemnly',
#  'encroach',
#  'incalculable',
#  'accustom',
#  'palladium',
#  'Jealous',
#  'discountenancing',
#  'indignantly',
#  'frowning',
#  'alienate',
#  'enfeeble',
#  'link',
#  'numberless',
#  'obstructed',
#  'deluge',
#  'victorious',
#  'lawgivers',
#  'freeman',
#  'philanthropist',
#  'practicability',
#  'extricate',
#  'Constantly',
#  'reconciling',
#  'unavoidably',
#  'invaluable',
#  'overrule',
#  'accompany',
#  'avowal',
#  'imitating',
#  'superiors',
#  'calendar',
#  'intellect',
#  'Unlike',
#  'memorable',
#  'sensibly',
#  'unwavering',
#  'deserted',
#  'ungrateful',
#  'efficiently',
#  'performs',
#  'imperious',
#  'Position',
#  'bounteous',
#  'Distinct',
#  'prospective',
#  'staple',
#  'confessedly',
#  'counteracted',
#  'innumerable',
#  'excepting',
#  'provident',
#  'Half',
#  'teeming',
#  'remotest',
#  'compacts',
#  'implicit',
#  'undeviating',
#  'prosperously',
#  'unanswerably',
#  'impresses',
#  'countless',
#  'predicted',
#  'Latent',
#  'unfriendly',
#  'theorists',
#  'overbalanced',
#  'hastily',
#  'murmur',
#  'alacrity',
#  'uniformly',
#  'outrun',
#  'contending',
#  'exasperation',
#  'preserves',
#  'exhibitions',
#  'coercive',
#  'Occasionally',
#  'outrunning',
#  'denounced',
#  'assuredly',
#  'assumption',
#  'abridging',
#  'unfitness',
#  'foresaw',
#  'Actual',
#  'inviting',
#  'Certain',
#  'multiplication',
#  'conjecture',
#  'doubled',
#  'incredibly',
#  'averted',
#  'chain',
#  'balancing',
#  'insurmountable',
#  'arose',
#  'uninjured',
#  'Overlooking',
#  'remarkably',
#  'vibrations',
#  'tended',
#  'elevate',
#  'renown',
#  'deviation',
#  'Amidst',
#  'gratified',
#  'chair',
#  'opponent',
#  'slaveholding',
#  'authorizes',
#  'terrifying',
#  'predominating',
#  'governs',
#  'reply',
#  'Present',
#  'viewing',
#  'explicitly',
#  'parted',
#  'referring',
#  'minute',
#  'obtrusive',
#  'intelligible',
#  'sedulously',
#  'avowing',
#  'disclaim',
#  'meddle',
#  'molest',
#  'exhaustless',
#  'atone',
#  'twice',
#  'unsurpassed',
#  'agreeing',
#  'evening',
#  'solicit',
#  'pleasantness',
#  'residue',
#  'consul',
#  'candidates',
#  'obtaining',
#  'indignant',
#  'fiat',
#  'delusion',
#  'approving',
#  'uttered',
#  'exonerated',
#  'classed',
#  'deceive',
#  'modify',
#  'admissions',
#  'Beneficent',
#  'intrust',
#  'provincial',
#  'democrat',
#  'console',
#  'sentence',
#  'banishment',
#  'Far',
#  'guilt',
#  'unrestrained',
#  'Stages',
#  'restricted',
#  'sententious',
#  'treats',
#  'intrinsic',
#  'unpatriotic',
#  'Limited',
#  'virtual',
#  'assurances',
#  'extensively',
#  'correctives',
#  'eligibility',
#  'lamented',
#  'amendatory',
#  'invidious',
#  'enumerate',
#  'disfigure',
#  'obliges',
#  'insatiable',
#  'worm',
#  'strengthens',
#  'victim',
#  'enjoined',
#  'solecism',
#  'annul',
#  'whereas',
#  'thirds',
#  'plural',
#  'operated',
#  'apparently',
#  'conceiving',
#  'maturing',
#  'preposterous',
#  'triple',
#  'acquires',
#  'consummating',
#  'inexpedient',
#  'recommending',
#  'employments',
#  'partaking',
#  'umpire',
#  'subdivision',
#  'secondly',
#  'thirdly',
#  'violative',
#  'Madison',
#  'recognitions',
#  'Upward',
#  'advocates',
#  'absorbed',
#  'consolidated',
#  'seized',
#  'casual',
#  'observer',
#  'appearance',
#  'undercurrent',
#  'seasonably',
#  'antifederal',
#  'overshadowed',
#  'radically',
#  'distributer',
#  'trifling',
#  'quadrupled',
#  'forbearing',
#  'Commander',
#  'Armies',
#  'mixed',
#  'termed',
#  'contradistinction',
#  'stamp',
#  'monarchical',
#  'custody',
#  'mischievous',
#  'Emperor',
#  'silenced',
#  'allusion',
#  'knight',
#  'insensible',
#  'drawing',
#  'removable',
#  'Secretary',
#  'immunity',
#  'unbiased',
#  'pockets',
#  'pliant',
#  'legacies',
#  'whomsoever',
#  'presses',
#  'varnish',
#  'impropriety',
#  'authorizing',
#  'forbidden',
#  'origination',
#  'isle',
#  'houses',
#  'agreeably',
#  'assigns',
#  'ascribed',
#  'Connected',
#  'mutation',
#  'hoards',
#  'sinking',
#  'penury',
#  'nobleness',
#  'neck',
#  'usury',
#  'Amongst',
#  'exterior',
#  'camp',
#  'humiliations',
#  'orators',
#  'stupid',
#  'insisted',
#  'interpreted',
#  'Mischievous',
#  'ineffectual',
#  'architects',
#  'separating',
#  'distinctly',
#  'precluded',
#  'requiring',
#  'resemble',
#  'fleet',
#  'Greece',
#  'subsequently',
#  'mainly',
#  'attributed',
#  'owing',
#  'Cantons',
#  'discrepancy',
#  'permanency',
#  'Content',
#  'clothes',
#  'harbingers',
#  'copartnership',
#  'allied',
#  'intangible',
#  'alienation',
#  'imprudent',
#  'disparage',
#  'proverbial',
#  'Unpleasant',
#  'jurisdictions',
#  'ruling',
#  'enthusiast',
#  'Utopian',
#  'scheming',
#  'politician',
#  'demagogue',
#  'balm',
#  'historians',
#  'attributing',
#  'writings',
#  'warped',
#  'unwillingness',
#  'whence',
#  'trick',
#  'warning',
#  'Cromwell',
#  'Bolivar',
#  'Christs',
#  'Savior',
#  'disciples',
#  'distinguishing',
#  'detect',
#  'counterfeit',
#  'employs',
#  'vindictive',
#  'excision',
#  'excrescence',
#  'fastened',
#  'restores',
#  'fails',
#  'subsists',
#  'pretension',
#  ...]

# %%
x=set(text1)
u=list(x)
u
# Out:
# ['store',
#  'amusing',
#  'clenching',
#  'informed',
#  'lacks',
#  'with',
#  'SETH',
#  'homewardbound',
#  'relations',
#  'heartily',
#  'stature',
#  'Placing',
#  'picked',
#  'signers',
#  'villany',
#  'irreverence',
#  'details',
#  'en',
#  'engendered',
#  'Sleeping',
#  'boastful',
#  'leaves',
#  'streamers',
#  'viewed',
#  'blew',
#  'east',
#  'needs',
#  'attainable',
#  'Merely',
#  'Gifted',
#  'swarthy',
#  'whimsicalities',
#  'annual',
#  'changeful',
#  'lbs',
#  'descends',
#  'Powers',
#  'barber',
#  'jackal',
#  'RIGGING',
#  'stiffening',
#  'patrician',
#  'trunk',
#  'unprofessional',
#  'personally',
#  'species',
#  'flags',
#  'watch',
#  'etc',
#  'durable',
#  'crimsoned',
#  'Owing',
#  'Smeerenberg',
#  'hydrants',
#  'empire',
#  'tattooing',
#  'planed',
#  'Soothed',
#  'bloated',
#  'respirations',
#  'manikin',
#  'unsocial',
#  'ethereal',
#  'inoffensive',
#  'Whereas',
#  'breadfruit',
#  'jib',
#  'tower',
#  'stillness',
#  'context',
#  'frisky',
#  'Mendanna',
#  'valiant',
#  'observing',
#  'bagged',
#  'failures',
#  'View',
#  'inelegant',
#  'MAIN',
#  'harpoon',
#  'humming',
#  'Eh',
#  'hymns',
#  'convenient',
#  'packet',
#  'cautiously',
#  'olive',
#  'Subtilize',
#  'estimate',
#  'smites',
#  'Fossil',
#  'obstreperously',
#  'loomed',
#  'loftiest',
#  'masonry',
#  'pruning',
#  'throats',
#  'common',
#  'A',
#  'moor',
#  'device',
#  'havens',
#  'doorway',
#  'stump',
#  'vertu',
#  'thrill',
#  'impulsively',
#  'peril',
#  'suicide',
#  'tied',
#  'whiteness',
#  'fondly',
#  'Could',
#  'asleep',
#  'buckets',
#  'insist',
#  '1788',
#  'digestive',
#  'shooks',
#  'prevent',
#  'Greenland',
#  'SIR',
#  'School',
#  'yon',
#  'roughly',
#  'conjunctures',
#  'coal',
#  'junior',
#  'Into',
#  'pledges',
#  'Bad',
#  'shut',
#  'wailing',
#  'graved',
#  'scorn',
#  'actively',
#  'exception',
#  'suckling',
#  'Deuteronomy',
#  'symbolized',
#  'SIBBALD',
#  'sympathies',
#  'section',
#  'performed',
#  'triply',
#  'shipwrecked',
#  'Here',
#  'Squire',
#  'midship',
#  'humor',
#  'Desecrated',
#  'attached',
#  'straightened',
#  'creepingly',
#  'Quoin',
#  'inflexible',
#  'burnt',
#  'shallow',
#  'squatting',
#  'comprising',
#  'treat',
#  'herrings',
#  'riding',
#  'SPERMA',
#  'bounties',
#  'clumped',
#  'coiled',
#  'dood',
#  'presaged',
#  'Borneo',
#  'penniless',
#  'serves',
#  'escaped',
#  'child',
#  'accessible',
#  'Pacific',
#  'hunch',
#  'marking',
#  'Essex',
#  'chucks',
#  'wills',
#  'Dugongs',
#  'two',
#  'mealtimes',
#  'inboard',
#  'noticing',
#  'craziness',
#  'overleap',
#  'bundles',
#  'Adam',
#  'partner',
#  'enshrined',
#  'soapstone',
#  'blunted',
#  'careening',
#  'Purchas',
#  'hardly',
#  'namely',
#  '1726',
#  'gazer',
#  'goodness',
#  'seeming',
#  'angularly',
#  'fullers',
#  '1652',
#  'characteristic',
#  'Artedi',
#  'glistened',
#  'pate',
#  'whistling',
#  'reciprocally',
#  'misery',
#  'la',
#  'knives',
#  'casually',
#  'glarings',
#  '!',
#  'narwhale',
#  'benefit',
#  'dawning',
#  'influential',
#  'phospher',
#  'COWLEY',
#  'accomplishment',
#  'revolvingly',
#  'Something',
#  'burial',
#  'tiger',
#  'merchantmen',
#  'owners',
#  'pitied',
#  'Philistines',
#  'THESE',
#  'poncho',
#  'Earl',
#  'lard',
#  'seats',
#  'fasting',
#  'ungraduated',
#  'boatheader',
#  'Betty',
#  'throes',
#  'Justinian',
#  'barb',
#  'collect',
#  'Tahiti',
#  'horrible',
#  '440',
#  'neat',
#  'swindle',
#  'exhaustion',
#  'concentric',
#  'deal',
#  'night',
#  'corporeally',
#  'finish',
#  'imparted',
#  'Charity',
#  'beholder',
#  'boil',
#  'THEE',
#  'attaining',
#  'gowns',
#  'garments',
#  'Cursed',
#  'caking',
#  'enlarge',
#  'danger',
#  'Steelkilt',
#  'painfulness',
#  'baggage',
#  'mixed',
#  'Loom',
#  'whitenesses',
#  'whether',
#  'intensely',
#  'addition',
#  'Vancouver',
#  'equivalent',
#  'Abjectus',
#  'quarried',
#  'secreted',
#  'hare',
#  'remonstrating',
#  'cherubim',
#  '180',
#  'mystifications',
#  'poop',
#  'Vice',
#  'Muffled',
#  'statement',
#  'caput',
#  'Trumpet',
#  'stock',
#  'wouldn',
#  'projections',
#  'wakeful',
#  'supremacy',
#  'guiltiness',
#  'borders',
#  'patience',
#  'neighbor',
#  'leisure',
#  'Woods',
#  'straight',
#  'Erie',
#  'dart',
#  'virtues',
#  'enriched',
#  'haven',
#  'heterogeneous',
#  'contribute',
#  'clamped',
#  'specific',
#  'London',
#  'bluff',
#  'Northern',
#  'jeering',
#  'extant',
#  'mingled',
#  'enlivened',
#  'oakum',
#  'fluking',
#  'survive',
#  'core',
#  'huge',
#  'richly',
#  'lowly',
#  'unfearing',
#  'rafts',
#  'agree',
#  'unsuccessful',
#  'insinuates',
#  'Abel',
#  'paler',
#  'Beware',
#  'barometer',
#  'constituting',
#  'CONTESTED',
#  'lividly',
#  'diaboli',
#  'oneness',
#  'banked',
#  'lingering',
#  'mystifying',
#  'RAZOR',
#  'adieux',
#  'indomitableness',
#  'fitful',
#  'dearly',
#  'tempest',
#  'gums',
#  'Read',
#  'older',
#  'trample',
#  'spiritually',
#  'threw',
#  'likened',
#  'Lad',
#  'halting',
#  'designated',
#  'brimmers',
#  'grog',
#  'leash',
#  'shrines',
#  'truthfully',
#  'shrunk',
#  'laughter',
#  'comber',
#  'protected',
#  'initiated',
#  'foiled',
#  'SCENE',
#  'discovered',
#  'disobey',
#  'tickle',
#  'alleged',
#  'root',
#  'East',
#  'Sub',
#  '3d',
#  'envious',
#  'modelled',
#  'argue',
#  'Lackaday',
#  'papered',
#  'lighted',
#  'depend',
#  'cross',
#  'dreamiest',
#  'bill',
#  'Drive',
#  'pint',
#  'dungeoned',
#  'Scales',
#  'obedience',
#  'battles',
#  'baboon',
#  'expanded',
#  'substance',
#  'improving',
#  'moderns',
#  'slided',
#  'WHALES',
#  'We',
#  'partiality',
#  'sabbee',
#  'undeliverable',
#  'fared',
#  'ark',
#  'bone',
#  'unfamiliar',
#  'epitaphs',
#  'spoils',
#  'imputable',
#  'told',
#  'counted',
#  'wiseish',
#  'isolated',
#  'descending',
#  'frogs',
#  'spite',
#  'Islands',
#  'Nicholas',
#  'jub',
#  'assertion',
#  'worlds',
#  'Peru',
#  'stiffest',
#  'risks',
#  'pickled',
#  'exhilarating',
#  'cleets',
#  'report',
#  'manifold',
#  'Enderbies',
#  'assailable',
#  'impelling',
#  'tormented',
#  'planned',
#  'clipped',
#  'haunt',
#  'completed',
#  'must',
#  'youngest',
#  'hemp',
#  'ferrule',
#  '):',
#  'lords',
#  'contradicted',
#  'Lima',
#  'throne',
#  'Somehow',
#  'infinity',
#  'premium',
#  'ponderosity',
#  'JOHNSON',
#  'sing',
#  'queen',
#  'cucumbers',
#  'overwhelmed',
#  'Mogul',
#  'tingled',
#  'begin',
#  'tellin',
#  'weepons',
#  'engines',
#  'kitten',
#  'Furl',
#  'restored',
#  'meanings',
#  'twas',
#  'towards',
#  'previous',
#  'heliotrope',
#  'hopeless',
#  'Cellini',
#  'Vermont',
#  'Wafer',
#  'flowered',
#  'stript',
#  'inexperienced',
#  'clever',
#  'prophecies',
#  'flickering',
#  'privateers',
#  'main',
#  'insular',
#  'mint',
#  'Constantinople',
#  'Dutch',
#  'train',
#  'knocks',
#  'begotten',
#  'expanses',
#  'opposition',
#  'priest',
#  'crookedly',
#  'group',
#  'plainly',
#  'dragons',
#  'brimming',
#  'hooped',
#  'uncompromisedness',
#  'quaked',
#  'pipe',
#  'Years',
#  'shy',
#  'relish',
#  'staff',
#  'Therefore',
#  'quarter',
#  'admirers',
#  'robustness',
#  '62',
#  'rallied',
#  'sorely',
#  'shone',
#  'goring',
#  'surgeons',
#  'special',
#  'numberless',
#  'Southern',
#  'Welding',
#  'BARON',
#  'impeach',
#  'exiled',
#  'disproved',
#  'fond',
#  'fleshy',
#  'Moving',
#  'animals',
#  'emotions',
#  'ISOLATOES',
#  'hypo',
#  'unceasingly',
#  'wounds',
#  'stooped',
#  'roses',
#  'invunerable',
#  'kidnapped',
#  'porthole',
#  'si',
#  'Wolf',
#  'illustration',
#  'trouble',
#  'Lifted',
#  'rhubarb',
#  'unmethodically',
#  'philosopher',
#  'Zodiac',
#  'wasn',
#  'shinbones',
#  'prompts',
#  'mothers',
#  'entrenchments',
#  'fat',
#  'Step',
#  'sprung',
#  'Paean',
#  'promptitude',
#  'mumbling',
#  'measurement',
#  'regards',
#  'murdering',
#  'vermillion',
#  'Striking',
#  'lapsed',
#  'spectralness',
#  'solved',
#  'voracious',
#  'christenings',
#  'wails',
#  'assistance',
#  'Porpoises',
#  'arrives',
#  'ardour',
#  'gently',
#  'elemental',
#  'crick',
#  'strips',
#  'Beneath',
#  'predecessor',
#  'shoved',
#  'mischief',
#  'necessity',
#  'hair',
#  'splice',
#  'ineffably',
#  'meal',
#  'evince',
#  'revery',
#  'quarrel',
#  'Simeon',
#  'claps',
#  'helping',
#  'shaded',
#  'History',
#  'waste',
#  'noting',
#  'strained',
#  'heavens',
#  'mortalities',
#  'pod',
#  'heartlessness',
#  'sourceless',
#  'friends',
#  'WAY',
#  'hag',
#  'mills',
#  'nod',
#  'collecting',
#  'traveller',
#  'brightest',
#  'fast',
#  'hawser',
#  'intelligence',
#  'comical',
#  'HIMSELF',
#  'condemned',
#  'glancing',
#  'vigilance',
#  'passages',
#  'counterfeit',
#  '104',
#  'beaten',
#  'beards',
#  'relieving',
#  'casts',
#  'claim',
#  'contortions',
#  'Instead',
#  'candelabra',
#  'drawlingly',
#  'Macy',
#  'Christian',
#  'tenth',
#  'thimbleful',
#  'Andes',
#  'ISHMAEL',
#  'tastes',
#  'rigger',
#  'purposely',
#  'MUTINEER',
#  'Hish',
#  'contraband',
#  'sworn',
#  'Taurus',
#  'Arrayed',
#  'chorus',
#  'intensified',
#  'disbelief',
#  'widowed',
#  'restore',
#  'oarsman',
#  'Libra',
#  'sentry',
#  'betters',
#  'spouted',
#  'thousandth',
#  'cluster',
#  'intermitting',
#  'digest',
#  'timid',
#  'dis',
#  'Toes',
#  'Erskine',
#  'juniper',
#  'Canaan',
#  'tramping',
#  'yet',
#  'splintered',
#  'ghastliness',
#  'authentic',
#  'roods',
#  'crocodile',
#  'matched',
#  'swagger',
#  'insult',
#  'raked',
#  'faint',
#  'wakes',
#  'expertness',
#  'allusion',
#  'Dome',
#  'serenely',
#  'contradictory',
#  'spiralizations',
#  'Want',
#  'authority',
#  'thoughtlessness',
#  'Bachelor',
#  'Typhoon',
#  'intertangled',
#  'evilly',
#  'so',
#  'politely',
#  'Grant',
#  'grunted',
#  'hastily',
#  'tensing',
#  'tremendous',
#  'perfumery',
#  'ebony',
#  'conciliating',
#  'zoned',
#  'pickles',
#  'killers',
#  'intentions',
#  'Western',
#  'comprised',
#  'Wa',
#  'peeped',
#  'confidentially',
#  'convulsive',
#  'Respectively',
#  'OUT',
#  'melting',
#  'serried',
#  'Diminish',
#  'Mixed',
#  'clasp',
#  'Archy',
#  'thawed',
#  'proceed',
#  'paved',
#  'foible',
#  'Stretched',
#  'canonized',
#  'Albemarle',
#  'streets',
#  'presentment',
#  'transparent',
#  'weariness',
#  'settee',
#  'Martha',
#  'cringed',
#  'frosted',
#  'freshness',
#  'lead',
#  '98',
#  'Oh',
#  'Every',
#  'ober',
#  'begun',
#  'involves',
#  'watchman',
#  'abed',
#  'jurisprudence',
#  'writer',
#  'Potluck',
#  'Mad',
#  'rotund',
#  'ship',
#  'abhorrent',
#  'yield',
#  'rivals',
#  'Isthmus',
#  'muffled',
#  'Least',
#  'incompetent',
#  'drippings',
#  'interlacings',
#  'BALLENA',
#  'demand',
#  'buttons',
#  'gardening',
#  'crime',
#  'matter',
#  '33',
#  'sermon',
#  'Beach',
#  'Indies',
#  'sedentary',
#  'Dish',
#  'throttle',
#  'fervent',
#  'superadd',
#  'spectral',
#  'roofed',
#  'knees',
#  'scrupulous',
#  'hacked',
#  'scrutinizing',
#  'struggling',
#  'unwarrantable',
#  'pelt',
#  'militia',
#  '!--"',
#  'flail',
#  'whirling',
#  'odorless',
#  'grazes',
#  'rippling',
#  'fatality',
#  'infatuation',
#  'passage',
#  'subtleness',
#  'unexempt',
#  'churning',
#  'persecutor',
#  'overpowered',
#  'rat',
#  'portentousness',
#  'Grub',
#  'unlighted',
#  'Spaniards',
#  'I',
#  'counting',
#  'affidavit',
#  'HAILS',
#  'Burton',
#  'planted',
#  'Not',
#  'barred',
#  'dislodged',
#  'income',
#  'clover',
#  'comparative',
#  'Omen',
#  'corals',
#  'demselves',
#  'soundest',
#  'engaged',
#  'local',
#  'pallet',
#  'adopting',
#  'Virgo',
#  'thunderings',
#  'Astern',
#  'distinctive',
#  'incommoding',
#  'shudder',
#  'ma',
#  'using',
#  'effectual',
#  'apprehensions',
#  'village',
#  'Fetch',
#  'dried',
#  'Congregational',
#  'pins',
#  'togged',
#  'stains',
#  'plentifully',
#  'touches',
#  'enterprise',
#  'corrupted',
#  'opera',
#  'regardless',
#  'confidently',
#  'inaccessible',
#  'heavers',
#  'repetitions',
#  'inside',
#  'accustomed',
#  'sense',
#  'strainings',
#  'gripping',
#  'blackened',
#  'Syrian',
#  'yonder',
#  'cent',
#  'flank',
#  'softener',
#  'VIIIth',
#  'anticipative',
#  'bushy',
#  'spades',
#  'flowery',
#  'uneasy',
#  'mood',
#  'Claus',
#  'knitted',
#  'learnt',
#  'gaped',
#  'questioning',
#  'Rose',
#  'cutting',
#  'Alone',
#  'objects',
#  'sown',
#  'shrivelled',
#  'goods',
#  'minded',
#  'domed',
#  '100',
#  'ignite',
#  'tasting',
#  'oozy',
#  'print',
#  'obstinate',
#  'Matse',
#  'cruises',
#  'responsible',
#  'WINDOWS',
#  'brace',
#  'SPOUTING',
#  'fins',
#  'EX',
#  'strikes',
#  'sundry',
#  'blacks',
#  'zones',
#  'Dons',
#  'Marine',
#  'jerking',
#  'companion',
#  'slewed',
#  'Going',
#  'wholesome',
#  'Cuba',
#  'asunder',
#  'GAM',
#  'contest',
#  'vacation',
#  'plazza',
#  'caterpillar',
#  'aggregate',
#  'famous',
#  'spasmodic',
#  'miasmas',
#  'Crish',
#  'dyspepsias',
#  'vernacular',
#  'relieved',
#  'flailing',
#  'bloom',
#  'dining',
#  'placelessly',
#  'chewed',
#  'buoyant',
#  'yourself',
#  'epicures',
#  'HEREABOUTS',
#  'Blind',
#  'sinecure',
#  'Spermacetti',
#  'superstitiously',
#  'seen',
#  'unsay',
#  'meet',
#  'salt',
#  'masters',
#  'pedestal',
#  'accurately',
#  'invasion',
#  'salutations',
#  'diverting',
#  'CLOSES',
#  'conceived',
#  'velvet',
#  'entreat',
#  'zeal',
#  'mountain',
#  'perceiving',
#  'marchant',
#  'They',
#  'habituation',
#  'Bouton',
#  'piggin',
#  'Court',
#  'rehearsed',
#  'Free',
#  'convenience',
#  'winks',
#  'repellingly',
#  'punctually',
#  'gaunt',
#  'uncorking',
#  'extracted',
#  'FLOOD',
#  'groin',
#  'Cod',
#  'Main',
#  'Inn',
#  'escaping',
#  'perpetuated',
#  'kneel',
#  'Broad',
#  'exchanged',
#  'entering',
#  'omniscient',
#  'vivaciously',
#  'Kick',
#  'smiled',
#  'dictatorship',
#  'palpably',
#  'Martin',
#  'premised',
#  'mutineer',
#  'pledge',
#  'Nature',
#  'circle',
#  'conspire',
#  'lasted',
#  'till',
#  'urn',
#  'sportively',
#  'cannikin',
#  ...]

# %%
u[:20]
# Out:
# ['store',
#  'amusing',
#  'clenching',
#  'informed',
#  'lacks',
#  'with',
#  'SETH',
#  'homewardbound',
#  'relations',
#  'heartily',
#  'stature',
#  'Placing',
#  'picked',
#  'signers',
#  'villany',
#  'irreverence',
#  'details',
#  'en',
#  'engendered',
#  'Sleeping']

# %%
x=set(text1)
u=list(x)
longest_word = [b for b in u if len(b)>15]
longest_word
# Out:
# ['uncompromisedness',
#  'characteristically',
#  'supernaturalness',
#  'circumnavigations',
#  'uncomfortableness',
#  'indiscriminately',
#  'CIRCUMNAVIGATION',
#  'subterraneousness',
#  'hermaphroditical',
#  'physiognomically',
#  'irresistibleness',
#  'apprehensiveness',
#  'circumnavigation',
#  'Physiognomically',
#  'indispensableness',
#  'undiscriminating',
#  'circumnavigating',
#  'comprehensiveness',
#  'cannibalistically',
#  'simultaneousness',
#  'uninterpenetratingly',
#  'superstitiousness',
#  'responsibilities',
#  'preternaturalness']
